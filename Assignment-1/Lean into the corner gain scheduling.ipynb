# %%
"""
Comfort-first lean control simulation with 2D gain scheduling for Kp and Krate.

Scheduling:
 - Kp and Krate are scheduled smoothly based on (v, |kappa|)
 - Ki remains constant
 - Bilinear interpolation on a small grid ensures no jumps

Everything else preserved from your comfort-first setup:
 - curvature ramp in/out
 - PI outer loop -> rate command
 - rate servo feedback torque
 - feedforward = kphi * phi_des
 - comfort metric: a_lat_feel = g*(phi_des - phi)
"""

import math
import numpy as np
import matplotlib.pyplot as plt


# -----------------------------
# VEHICLE / PLANT PARAMETERS
# -----------------------------
Iphi = 600.0          # [kg*m^2]
kphi = 10000.0        # [N*m/rad]
cphi = 2000.0         # [N*m*s/rad]

m = 1500.0            # [kg] (not used directly in comfort-first)
h = 0.55              # [m]


# -----------------------------
# CONTROLLER BASE (used if scheduling falls to single-point)
# -----------------------------
# Note: we will schedule Kp and Krate; these base values remain as fallbacks
Kp_base = 0.8              # [1/s] (not used directly once scheduling active)
Ki = 0.10                  # [1/s^2] (kept constant)
Krate_base = 6000.0        # [N*m*s/rad] (not used directly once scheduling active)

phi_max_deg = 10.0            # [deg] roll angle limit
phi_dot_cmd_max_deg_s = 6.0   # [deg/s] comfort-first roll-rate command limit


# -----------------------------
# TURN SCENARIO
# -----------------------------
v = 10.0              # [m/s] (scheduling will use this)
R = -200.0            # [m] (+left, -right)

turn_start_time = 1.0  # [s]
turn_end_time   = 10.0 # [s] fully back to straight by this time
turn_ramp_time  = 1.0  # [s] ramp in and ramp out duration (curvature)


# -----------------------------
# GAIN SCHEDULING DEFINITIONS (2D table over v and |kappa|)
# -----------------------------
# grids
v_grid = np.array([5.0, 10.0, 20.0])                       # m/s
kappa_grid = np.array([0.0, 1/400.0, 1/200.0, 1/100.0])    # 1/m

# scheduling tables (rows -> v_grid, cols -> kappa_grid)
Kp_table = np.array([
    [0.5, 0.7, 0.9, 1.1],   # v=5
    [0.6, 0.8, 1.0, 1.2],   # v=10
    [0.8, 1.0, 1.2, 1.4],   # v=20
], dtype=float)

Krate_table = np.array([
    [4000, 5000, 6000, 7500],  # v=5
    [4500, 6000, 7000, 8500],  # v=10
    [6000, 7500, 9000, 11000], # v=20
], dtype=float)

# clamps for safety
Kp_min, Kp_max = 0.3, 2.0
Krate_min, Krate_max = 2000.0, 20000.0


# -----------------------------
# SIMULATION
# -----------------------------
dt = 0.001            # [s]
T = 15.0              # [s]

g = 9.81
phi_max = math.radians(phi_max_deg)
phi_dot_cmd_max = math.radians(phi_dot_cmd_max_deg_s)


def clip(x, lo, hi):
    return max(lo, min(hi, x))

def smoothstep01(x):
    """C1-continuous 0->1 ramp for x in [0,1]."""
    x = clip(x, 0.0, 1.0)
    return x * x * (3.0 - 2.0 * x)


# --- helpers for bilinear interpolation ---
def lerp(a, b, w):
    return a + w * (b - a)

def find_interval(x, grid):
    """
    Returns (i0, i1, w) such that x is between grid[i0] and grid[i1]
    and w in [0,1] is interpolation weight toward i1.
    Clamps to edges.
    """
    if x <= grid[0]:
        return 0, 0, 0.0
    if x >= grid[-1]:
        return len(grid) - 1, len(grid) - 1, 0.0

    for i in range(len(grid) - 1):
        if grid[i] <= x <= grid[i + 1]:
            w = (x - grid[i]) / (grid[i + 1] - grid[i])
            return i, i + 1, w

    return len(grid) - 1, len(grid) - 1, 0.0

def bilinear_2d(x, y, x_grid, y_grid, table):
    """
    Bilinear interpolation over (x_grid, y_grid) for value at (x,y).
    table shape: (len(x_grid), len(y_grid))
    """
    x0, x1, wx = find_interval(x, x_grid)
    y0, y1, wy = find_interval(y, y_grid)

    f00 = table[x0, y0]
    f01 = table[x0, y1]
    f10 = table[x1, y0]
    f11 = table[x1, y1]

    f0 = lerp(f00, f01, wy)
    f1 = lerp(f10, f11, wy)
    return lerp(f0, f1, wx)


# Time
N = int(T / dt) + 1
t = np.linspace(0.0, T, N)

# States and signals
phi = np.zeros(N)          # [rad]
phi_dot = np.zeros(N)      # [rad/s]

phi_des = np.zeros(N)      # [rad]
phi_dot_cmd = np.zeros(N)  # [rad/s]

tau_act = np.zeros(N)      # [N*m]
tau_ff = np.zeros(N)       # [N*m]
tau_fb = np.zeros(N)       # [N*m]

ay = np.zeros(N)           # [m/s^2]
kappa_arr = np.zeros(N)    # [1/m]

e_arr = np.zeros(N)        # [rad]
e_int_arr = np.zeros(N)    # [rad*s]

# Comfort metric: passenger felt lateral acceleration in vehicle frame (reduced-model)
a_lat_feel = np.zeros(N)   # [m/s^2]

# Scheduled gains logging
Kp_used = np.zeros(N)
Krate_used = np.zeros(N)

# PI integrator state
e_int = 0.0


for i in range(N - 1):
    ti = t[i]

    # -----------------------------
    # Comfort-first curvature profile: ramp in, hold, ramp out
    # -----------------------------
    if ti < turn_start_time:
        s = 0.0
    elif ti < turn_start_time + turn_ramp_time:
        xi = (ti - turn_start_time) / turn_ramp_time
        s = smoothstep01(xi)
    elif ti < turn_end_time - turn_ramp_time:
        s = 1.0
    elif ti < turn_end_time:
        xi = (ti - (turn_end_time - turn_ramp_time)) / turn_ramp_time
        s = 1.0 - smoothstep01(xi)
    else:
        s = 0.0

    # Curvature ramps from 0 -> 1/R -> 0 (signed)
    kappa = 0.0 if abs(R) < 1e-9 else (s / R)
    kappa_arr[i] = kappa

    # Lateral acceleration
    ay_i = v * v * kappa
    ay[i] = ay_i

    # Desired lean angle for comfort (full cancellation)
    phi_des_i = -math.atan(ay_i / g)
    phi_des_i = clip(phi_des_i, -phi_max, phi_max)
    phi_des[i] = phi_des_i

    # -----------------------------
    # Gain scheduling: schedule Kp and Krate based on (v, |kappa|)
    # -----------------------------
    kappa_mag = abs(kappa)
    Kp_sched = bilinear_2d(v, kappa_mag, v_grid, kappa_grid, Kp_table)
    Krate_sched = bilinear_2d(v, kappa_mag, v_grid, kappa_grid, Krate_table)

    # Clamp for safety
    Kp_sched = clip(Kp_sched, Kp_min, Kp_max)
    Krate_sched = clip(Krate_sched, Krate_min, Krate_max)

    Kp_used[i] = Kp_sched
    Krate_used[i] = Krate_sched

    # -----------------------------
    # Comfort metric (reduced-model): felt lateral accel ~ g*(phi_des - phi)
    # -----------------------------
    a_lat_feel[i] = g * (phi_des_i - phi[i])

    # -----------------------------
    # PI outer-loop using scheduled Kp
    # -----------------------------
    e = phi_des_i - phi[i]
    e_arr[i] = e
    e_int_arr[i] = e_int

    phi_dot_cmd_unsat = Kp_sched * e + Ki * e_int
    phi_dot_cmd_i = clip(phi_dot_cmd_unsat, -phi_dot_cmd_max, phi_dot_cmd_max)
    phi_dot_cmd[i] = phi_dot_cmd_i

    # Anti-windup
    saturated = abs(phi_dot_cmd_unsat - phi_dot_cmd_i) > 1e-12
    if (not saturated) or ((phi_dot_cmd_i == phi_dot_cmd_max and e < 0.0) or (phi_dot_cmd_i == -phi_dot_cmd_max and e > 0.0)):
        e_int += e * dt

    # -----------------------------
    # Feedforward + feedback torque (feedback uses scheduled Krate)
    # -----------------------------
    tau_ff_i = kphi * phi_des_i
    tau_ff[i] = tau_ff_i

    tau_fb_i = Krate_sched * (phi_dot_cmd_i - phi_dot[i])
    tau_fb[i] = tau_fb_i

    tau_act_i = tau_ff_i + tau_fb_i
    tau_act[i] = tau_act_i

    # -----------------------------
    # Plant dynamics:
    # I*phi_ddot + c*phi_dot + k*phi = tau_act
    # -----------------------------
    phi_ddot_i = (tau_act_i - cphi * phi_dot[i] - kphi * phi[i]) / Iphi

    # Integrate (semi-implicit Euler)
    phi_dot[i + 1] = phi_dot[i] + phi_ddot_i * dt
    phi[i + 1] = phi[i] + phi_dot[i + 1] * dt


# Fill last sample for plotting
phi_des[-1] = phi_des[-2]
phi_dot_cmd[-1] = phi_dot_cmd[-2]
tau_act[-1] = tau_act[-2]
tau_ff[-1] = tau_ff[-2]
tau_fb[-1] = tau_fb[-2]
ay[-1] = ay[-2]
kappa_arr[-1] = kappa_arr[-2]
e_arr[-1] = e_arr[-2]
e_int_arr[-1] = e_int
a_lat_feel[-1] = a_lat_feel[-2]
Kp_used[-1] = Kp_used[-2]
Krate_used[-1] = Krate_used[-2]


# -----------------------------
# PLOTS
# -----------------------------
plt.figure()
plt.plot(t, np.degrees(phi), label="phi (deg)")
plt.plot(t, np.degrees(phi_des), label="phi_des (deg)")
plt.axhline(phi_max_deg, linestyle="--")
plt.axhline(-phi_max_deg, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("roll angle (deg)")
plt.title("Roll angle tracking (comfort-first turn-in/out)")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, np.degrees(phi_dot), label="phi_dot (deg/s)")
plt.plot(t, np.degrees(phi_dot_cmd), label="phi_dot_cmd (deg/s)")
plt.axhline(phi_dot_cmd_max_deg_s, linestyle="--")
plt.axhline(-phi_dot_cmd_max_deg_s, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("roll rate (deg/s)")
plt.title("Roll rate and commanded roll rate")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, tau_act, label="tau_act = tau_ff + tau_fb (N*m)")
plt.plot(t, tau_ff, label="tau_ff (N*m)")
plt.plot(t, tau_fb, label="tau_fb (N*m)")
plt.xlabel("time (s)")
plt.ylabel("torque (N*m)")
plt.title("Actuator torques (comfort-first, effort allowed)")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, ay, label="a_y (m/s^2)")
plt.axhline(0.0, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("lateral acceleration (m/s^2)")
plt.title("Lateral acceleration profile (curvature ramp-in/out)")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, kappa_arr, label="curvature kappa (1/m)")
plt.axhline(0.0, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("curvature (1/m)")
plt.title("Curvature profile (0 → 1/R → 0)")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, np.degrees(e_arr), label="error e = phi_des - phi (deg)")
plt.plot(t, e_int_arr, label="integrator e_int (rad*s)")
plt.axhline(0.0, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("error / integrator")
plt.title("PI error and integrator state")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, a_lat_feel, label="felt lateral accel (m/s^2)")
plt.axhline(0.0, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("m/s^2")
plt.title("Passenger felt lateral acceleration (comfort metric)")
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(t, a_lat_feel / g, label="felt lateral accel (g)")
plt.axhline(0.0, linestyle="--")
plt.xlabel("time (s)")
plt.ylabel("g")
plt.title("Passenger felt lateral acceleration (in g)")
plt.legend()
plt.grid(True)

# Scheduled gains plots
plt.figure()
plt.plot(t, Kp_used, label="Kp (scheduled)")
plt.xlabel("time (s)")
plt.ylabel("Kp")
plt.title("Scheduled Kp over time")
plt.grid(True)
plt.legend()

plt.figure()
plt.plot(t, Krate_used, label="Krate (scheduled)")
plt.xlabel("time (s)")
plt.ylabel("Krate")
plt.title("Scheduled Krate over time")
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# # HW1 Problem 1 — Lean-Into-Corner Controller (Gain Scheduling)
# **Comfort-first design (PI outer loop + rate servo inner loop) with 2D gain scheduling for Kp and Krate.**
#
# **Author:** `<Your Name>`
# **Notebook:** `Lean into the corner gain scheduling.ipynb`
#
# **Purpose:**
# - Implement a comfort-first lean controller that leans the vehicle into turns to reduce passenger felt lateral acceleration.
# - Use a classical 2D gain scheduling approach where `Kp` and `Krate` are scheduled based on speed `v` and curvature magnitude `|kappa|`.
# - Provide plots for tracking, torque, scheduled gains, and comfort metric for analysis.

# %% [markdown]
# ## Overview and design choices
#
# **Design goals**
# - Prioritize passenger comfort (minimize felt lateral acceleration).
# - Smooth curvature ramp in/out to avoid jerk.
# - Maintain roll-angle limit (±10°) and roll-rate command limit (±6°/s).
#
# **Controller structure**
# - Outer loop: PI that computes desired roll-rate (`phi_dot_cmd`).
# - Inner loop: rate servo that produces feedback torque `tau_fb = Krate * (phi_dot_cmd - phi_dot)`.
# - Feedforward torque `tau_ff = kphi * phi_des` to hold the desired lean against roll stiffness.
# - Total actuator torque `tau_act = tau_ff + tau_fb`.
#
# **Scheduling**
# - `Kp` and `Krate` are scheduled smoothly on a small grid of (v, |kappa|) via bilinear interpolation.
# - `Ki` remains constant.

# %%
# Standard imports
import math
import numpy as np
import matplotlib.pyplot as plt

# plotting style (optional)
plt.style.use('dark_background')

# %%
# -----------------------------
# VEHICLE / PLANT PARAMETERS (editable)
# -----------------------------
Iphi = 600.0          # [kg*m^2] roll inertia
kphi = 10000.0        # [N*m/rad] roll stiffness
cphi = 2000.0         # [N*m*s/rad] roll damping

# constants (not used directly in comfort-first feedforward but keep for completeness)
m = 1500.0            # [kg] vehicle mass
h = 0.55              # [m] height to COM

# -----------------------------
# CONTROLLER DEFAULTS (editable)
# -----------------------------
Kp_base = 0.8              # fallback (1/s)
Ki = 0.10                  # integral gain (1/s^2)
Krate_base = 6000.0        # fallback (N*m*s/rad)

phi_max_deg = 10.0            # [deg]
phi_dot_cmd_max_deg_s = 6.0   # [deg/s]

# -----------------------------
# TURN SCENARIO (editable)
# -----------------------------
v = 10.0              # [m/s]  <-- change this cell to run different speeds
R = -200.0            # [m]  (signed; positive left, negative right)

# turn timing (seconds)
turn_start_time = 1.0
turn_end_time   = 10.0
turn_ramp_time  = 1.0

# -----------------------------
# SIMULATION params
# -----------------------------
dt = 0.001            # [s]
T = 15.0              # [s] (end of simulation)
g = 9.81
phi_max = math.radians(phi_max_deg)
phi_dot_cmd_max = math.radians(phi_dot_cmd_max_deg_s)

# %% [markdown]
# ## Gain scheduling tables
#
# We schedule `Kp` and `Krate` on a small 2D grid:
#
# - `v_grid` : rows (speeds)
# - `kappa_grid` : columns (curvature magnitude = |1/R|)
#
# Values in `Kp_table` and `Krate_table` are hand-designed baseline values for each (v, |kappa|) node.
# We bilinearly interpolate during the simulation to avoid jumps.

# %%
# -----------------------------
# GAIN SCHEDULING DEFINITIONS (2D table over v and |kappa|)
# -----------------------------
v_grid = np.array([5.0, 10.0, 20.0])                       # m/s
kappa_grid = np.array([0.0, 1/400.0, 1/200.0, 1/100.0])    # 1/m

Kp_table = np.array([
    [0.5, 0.7, 0.9, 1.1],   # v=5
    [0.6, 0.8, 1.0, 1.2],   # v=10
    [0.8, 1.0, 1.2, 1.4],   # v=20
], dtype=float)

Krate_table = np.array([
    [4000, 5000, 6000, 7500],  # v=5
    [4500, 6000, 7000, 8500],  # v=10
    [6000, 7500, 9000, 11000], # v=20
], dtype=float)

# safety clamps
Kp_min, Kp_max = 0.3, 2.0
Krate_min, Krate_max = 2000.0, 20000.0

# %% [markdown]
# ## Interpolation helpers
#
# We provide small utility functions:
# - `clip` : clamp values
# - `smoothstep01` : C1 ramp for curvature (makes turn-in/out smooth)
# - `lerp`, `find_interval`, `bilinear_2d` : for bilinear interpolation of gains

# %%
def clip(x, lo, hi):
    return max(lo, min(hi, x))

def smoothstep01(x):
    """C1-continuous 0->1 ramp for x in [0,1]."""
    x = clip(x, 0.0, 1.0)
    return x * x * (3.0 - 2.0 * x)

# lerp and bilinear interpolation
def lerp(a, b, w):
    return a + w * (b - a)

def find_interval(x, grid):
    if x <= grid[0]:
        return 0, 0, 0.0
    if x >= grid[-1]:
        return len(grid) - 1, len(grid) - 1, 0.0
    for i in range(len(grid) - 1):
        if grid[i] <= x <= grid[i + 1]:
            w = (x - grid[i]) / (grid[i + 1] - grid[i])
            return i, i + 1, w
    return len(grid) - 1, len(grid) - 1, 0.0

def bilinear_2d(x, y, x_grid, y_grid, table):
    x0, x1, wx = find_interval(x, x_grid)
    y0, y1, wy = find_interval(y, y_grid)
    f00 = table[x0, y0]
    f01 = table[x0, y1]
    f10 = table[x1, y0]
    f11 = table[x1, y1]
    f0 = lerp(f00, f01, wy)
    f1 = lerp(f10, f11, wy)
    return lerp(f0, f1, wx)

# %% [markdown]
# ## Simulation setup
#
# We integrate the reduced roll model:
#   I * phi_ddot + c * phi_dot + k * phi = tau_act
#
# At every timestep:
# - compute curvature `kappa` (smooth ramp in/out)
# - compute lateral acceleration `a_y = v^2 * kappa`
# - compute desired lean `phi_des = -atan(a_y / g)` (clipped to ±phi_max)
# - schedule gains Kp and Krate with bilinear interpolation on (v, |kappa|)
# - compute PI outer loop (with anti-windup) → phi_dot_cmd
# - compute tau_ff = kphi * phi_des
# - compute tau_fb = Krate * (phi_dot_cmd - phi_dot)
# - tau_act = tau_ff + tau_fb
# - integrate phi_ddot, phi_dot, phi (semi-implicit Euler)
# We log signals for plotting.

# %%
# ---- pre-allocate arrays ----
N = int(T / dt) + 1
t = np.linspace(0.0, T, N)

phi = np.zeros(N)
phi_dot = np.zeros(N)

phi_des = np.zeros(N)
phi_dot_cmd = np.zeros(N)

tau_act = np.zeros(N)
tau_ff = np.zeros(N)
tau_fb = np.zeros(N)

ay = np.zeros(N)
kappa_arr = np.zeros(N)

e_arr = np.zeros(N)
e_int_arr = np.zeros(N)

a_lat_feel = np.zeros(N)   # comfort metric
Kp_used = np.zeros(N)
Krate_used = np.zeros(N)

e_int = 0.0  # integrator state

for i in range(N - 1):
    ti = t[i]

    # curvature schedule (smooth ramp in/out)
    if ti < turn_start_time:
        s = 0.0
    elif ti < turn_start_time + turn_ramp_time:
        xi = (ti - turn_start_time) / turn_ramp_time
        s = smoothstep01(xi)
    elif ti < turn_end_time - turn_ramp_time:
        s = 1.0
    elif ti < turn_end_time:
        xi = (ti - (turn_end_time - turn_ramp_time)) / turn_ramp_time
        s = 1.0 - smoothstep01(xi)
    else:
        s = 0.0

    # signed curvature 0 -> 1/R -> 0
    kappa = 0.0 if abs(R) < 1e-9 else (s / R)
    kappa_arr[i] = kappa

    # lateral acceleration
    ay_i = v * v * kappa
    ay[i] = ay_i

    # desired lean for comfort (clipped)
    phi_des_i = -math.atan(ay_i / g)
    phi_des_i = clip(phi_des_i, -phi_max, phi_max)
    phi_des[i] = phi_des_i

    # schedule gains based on (v, |kappa|)
    kappa_mag = abs(kappa)
    Kp_sched = bilinear_2d(v, kappa_mag, v_grid, kappa_grid, Kp_table)
    Krate_sched = bilinear_2d(v, kappa_mag, v_grid, kappa_grid, Krate_table)
    Kp_sched = clip(Kp_sched, Kp_min, Kp_max)
    Krate_sched = clip(Krate_sched, Krate_min, Krate_max)
    Kp_used[i] = Kp_sched
    Krate_used[i] = Krate_sched

    # comfort metric (reduced-model)
    a_lat_feel[i] = g * (phi_des_i - phi[i])

    # PI outer-loop
    e = phi_des_i - phi[i]
    e_arr[i] = e
    e_int_arr[i] = e_int

    phi_dot_cmd_unsat = Kp_sched * e + Ki * e_int
    phi_dot_cmd_i = clip(phi_dot_cmd_unsat, -phi_dot_cmd_max, phi_dot_cmd_max)
    phi_dot_cmd[i] = phi_dot_cmd_i

    # anti-windup update
    saturated = abs(phi_dot_cmd_unsat - phi_dot_cmd_i) > 1e-12
    if (not saturated) or ((phi_dot_cmd_i == phi_dot_cmd_max and e < 0.0) or (phi_dot_cmd_i == -phi_dot_cmd_max and e > 0.0)):
        e_int += e * dt

    # feedforward + feedback torques
    tau_ff_i = kphi * phi_des_i
    tau_ff[i] = tau_ff_i
    tau_fb_i = Krate_sched * (phi_dot_cmd_i - phi_dot[i])
    tau_fb[i] = tau_fb_i
    tau_act_i = tau_ff_i + tau_fb_i
    tau_act[i] = tau_act_i

    # plant dynamics integration (semi-implicit Euler)
    phi_ddot_i = (tau_act_i - cphi * phi_dot[i] - kphi * phi[i]) / Iphi
    phi_dot[i + 1] = phi_dot[i] + phi_ddot_i * dt
    phi[i + 1] = phi[i] + phi_dot[i + 1] * dt

# fill final samples for plotting
phi_des[-1] = phi_des[-2]
phi_dot_cmd[-1] = phi_dot_cmd[-2]
tau_act[-1] = tau_act[-2]
tau_ff[-1] = tau_ff[-2]
tau_fb[-1] = tau_fb[-2]
ay[-1] = ay[-2]
kappa_arr[-1] = kappa_arr[-2]
e_arr[-1] = e_arr[-2]
e_int_arr[-1] = e_int
a_lat_feel[-1] = a_lat_feel[-2]
Kp_used[-1] = Kp_used[-2]
Krate_used[-1] = Krate_used[-2]

# %% [markdown]
# ## Plot descriptions
#
# - Roll angle and phi_des: check steady-state tracking and overshoot.
# - Roll rate and phi_dot_cmd: check commanded vs actual rates and comfort limit.
# - Torques: feedforward vs feedback vs total actuator torque.
# - Lateral acceleration and curvature: verify turn profile.
# - Error and integrator: PI behavior and anti-windup.
# - Passenger felt lateral acceleration: main comfort metric (m/s^2 and in g).
# - Scheduled Kp and Krate over time: ensures smooth scheduling during entry/exit.

# %%
# -----------------------------
# PLOTS
# -----------------------------
plt.figure(figsize=(8,4))
plt.plot(t, np.degrees(phi), label="phi (deg)")
plt.plot(t, np.degrees(phi_des), label="phi_des (deg)")
plt.axhline(phi_max_deg, linestyle="--", alpha=0.5)
plt.axhline(-phi_max_deg, linestyle="--", alpha=0.5)
plt.xlabel("time (s)"); plt.ylabel("roll angle (deg)")
plt.title("Roll angle tracking (comfort-first turn-in/out)")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,4))
plt.plot(t, np.degrees(phi_dot), label="phi_dot (deg/s)")
plt.plot(t, np.degrees(phi_dot_cmd), label="phi_dot_cmd (deg/s)")
plt.axhline(phi_dot_cmd_max_deg_s, linestyle="--", alpha=0.5)
plt.axhline(-phi_dot_cmd_max_deg_s, linestyle="--", alpha=0.5)
plt.xlabel("time (s)"); plt.ylabel("roll rate (deg/s)")
plt.title("Roll rate and commanded roll rate")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,4))
plt.plot(t, tau_act, label="tau_act = tau_ff + tau_fb (N*m)")
plt.plot(t, tau_ff, label="tau_ff (N*m)")
plt.plot(t, tau_fb, label="tau_fb (N*m)")
plt.xlabel("time (s)"); plt.ylabel("torque (N*m)")
plt.title("Actuator torques (comfort-first)")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,3))
plt.plot(t, ay, label="a_y (m/s^2)")
plt.axhline(0.0, linestyle="--", alpha=0.5)
plt.xlabel("time (s)"); plt.ylabel("lateral acceleration (m/s^2)")
plt.title("Lateral acceleration profile (curvature ramp-in/out)")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,3))
plt.plot(t, kappa_arr, label="curvature kappa (1/m)")
plt.xlabel("time (s)"); plt.ylabel("curvature (1/m)")
plt.title("Curvature profile (0 → 1/R → 0)")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,3))
plt.plot(t, np.degrees(e_arr), label="error e = phi_des - phi (deg)")
plt.plot(t, e_int_arr, label="integrator e_int (rad*s)")
plt.xlabel("time (s)"); plt.ylabel("error / integrator")
plt.title("PI error and integrator state")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,4))
plt.plot(t, a_lat_feel, label="felt lateral accel (m/s^2)")
plt.axhline(0.0, linestyle="--", alpha=0.5)
plt.xlabel("time (s)"); plt.ylabel("m/s^2")
plt.title("Passenger felt lateral acceleration (comfort metric)")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,3))
plt.plot(t, a_lat_feel / g, label="felt lateral accel (g)")
plt.axhline(0.0, linestyle="--", alpha=0.5)
plt.xlabel("time (s)"); plt.ylabel("g")
plt.title("Passenger felt lateral acceleration (in g)")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,3))
plt.plot(t, Kp_used, label="Kp (scheduled)")
plt.xlabel("time (s)"); plt.ylabel("Kp")
plt.title("Scheduled Kp over time")
plt.legend(); plt.grid(True)

plt.figure(figsize=(8,3))
plt.plot(t, Krate_used, label="Krate (scheduled)")
plt.xlabel("time (s)"); plt.ylabel("Krate")
plt.title("Scheduled Krate over time")
plt.legend(); plt.grid(True)

plt.show()

# %% [markdown]
# ## Quick experiments
#
# To test other speeds and radii:
# - Edit the `v` and `R` variables in the "Simulation / parameters" cell (cell 4).
# - Re-run the cells from the parameters cell (cell 4) downward (or use "Run All").
#
# Recommended test combinations:
# - v in {5, 10, 20} m/s
# - R in {±50, ±100, ±200, ±400} m

# %% [markdown]
# ## Interpretation tips / grader notes
#
# - If `phi` tracks `phi_des` closely and `a_lat_feel` is near zero during the hold phase, the controller is effectively canceling lateral acceleration via leaning.
# - Overshoot or oscillation indicates tuning needed (increase Krate for more damping; adjust Kp/Ki to change response).
# - Feedforward (tau_ff = kphi * phi_des) provides the steady holding torque. Feedback handles transient errors during transition.
# - The scheduled Kp/Krate plots should show smooth transitions during turn-in and turn-out (no jumps).
# - The comfort-first tuning limits phi_dot_cmd to ±6°/s and prioritizes comfortable passenger acceleration over minimizing actuator effort.

# %%
import pandas as pd

data = []

v_set = [5, 10, 15, 20]
R_set = [50, 100, 200, 400]

for v in v_set:
    for R in R_set:
        for sign in [-1, 1]:  # left/right
            R_signed = sign * R

            J, tr = simulate(best_theta, v, R_signed, return_traces=True)

            for i in range(len(tr["t"])):
                row = {
                    "v": v,
                    "kappa": tr["kappa"][i],
                    "t": tr["t"][i],
                    "a_lat_feel": tr["a_lat_feel"][i]
                }
                data.append(row)

df = pd.DataFrame(data)

# save dataset
df.to_csv("dataset.csv", index=False)

print("Dataset shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10 for sign in [-1, 1]:  # left/right
#      11     R_signed = sign * R
# ---> 13     J, tr = simulate(best_theta, v, R_signed, return_traces=True)
#      15     for i in range(len(tr["t"])):
#      16         row = {
#      17             "v": v,
#      18             "kappa": tr["kappa"][i],
#      19             "t": tr["t"][i],
#      20             "a_lat_feel": tr["a_lat_feel"][i]
#      21         }
#
# NameError: name 'simulate' is not defined
